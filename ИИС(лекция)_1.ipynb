# %%
import pandas as pd

from google.colab import files

# %%
# Загружаем нужные файлы из файловой системы
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5ad5b82c-4ebc-490a-9356-22a75301a009" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ad5b82c-4ebc-490a-9356-22a75301a009">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/cars.csv', delimiter = ',')
df
# Out:
#              Make         Model  Year      Style  Distance  \
# 0          Toyota         Prius  2011  Hatchback  195000.0
# 1         Renault  Grand Scenic  2014  Universal  135000.0
# 2      Volkswagen          Golf  1998  Hatchback       1.0
# 3         Renault        Laguna  2012  Universal  110000.0
# 4            Opel         Astra  2006  Universal  200000.0
# ...           ...           ...   ...        ...       ...
# 41002       Dacia     Logan Mcv  2015  Universal   89000.0
# 41003     Renault         Modus  2009  Hatchback     225.0
# 41004    Mercedes       E Class  2016      Sedan   50000.0
# 41005       Mazda             6  2006      Combi  370000.0
# 41006     Renault  Grand Scenic  2006    Minivan  300000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 0                    1800.0        Hybrid    Automatic       7750.0
# 1                    1500.0        Diesel       Manual       8550.0
# ...

# %%
# Просматриваем основную информацию о датафрейме с помощью функции .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41007 entries, 0 to 41006
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  41007 non-null  object
#  1   Model                 41007 non-null  object
#  2   Year                  41007 non-null  int64
#  3   Style                 41007 non-null  object
#  4   Distance              41007 non-null  float64
#  5   Engine_capacity(cm3)  41007 non-null  float64
#  6   Fuel_type             41007 non-null  object
#  7   Transmission          41007 non-null  object
#  8   Price(euro)           41007 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 2.8+ MB

# %%
# Функция duplicated возвращает датафрейм, в котором дублирующиеся значения заменены на значение True.
# Затем, мы подсчитываем сумму таких значений с помощью метода pd.Dataframe.sum()
df.duplicated().sum()
# Out:
# 3743

# %%
# После удаления повторяющихся значений, необходимо заново выставить индексы для
# каждой строки датафрейма, чтобы они шли по порядку
DF = df.drop_duplicates()

DF = DF.reset_index(drop=True)

DF
# Out:
#              Make         Model  Year      Style  Distance  \
# 0          Toyota         Prius  2011  Hatchback  195000.0
# 1         Renault  Grand Scenic  2014  Universal  135000.0
# 2      Volkswagen          Golf  1998  Hatchback       1.0
# 3         Renault        Laguna  2012  Universal  110000.0
# 4            Opel         Astra  2006  Universal  200000.0
# ...           ...           ...   ...        ...       ...
# 37259  Land Rover    Freelander  2002  Crossover  225000.0
# 37260       Dacia     Logan Mcv  2015  Universal   89000.0
# 37261     Renault         Modus  2009  Hatchback     225.0
# 37262       Mazda             6  2006      Combi  370000.0
# 37263     Renault  Grand Scenic  2006    Minivan  300000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 0                    1800.0        Hybrid    Automatic       7750.0
# 1                    1500.0        Diesel       Manual       8550.0
# ...

# %%
# Метод .head() датафрейма отображает заданное количество первых значений датафрейма
DF.head(6)
# Out:
#          Make         Model  Year      Style  Distance  Engine_capacity(cm3)  \
# 0      Toyota         Prius  2011  Hatchback  195000.0                1800.0
# 1     Renault  Grand Scenic  2014  Universal  135000.0                1500.0
# 2  Volkswagen          Golf  1998  Hatchback       1.0                1400.0
# 3     Renault        Laguna  2012  Universal  110000.0                1500.0
# 4        Opel         Astra  2006  Universal  200000.0                1600.0
# 5    Mercedes          Vito  2000   Microvan  300000.0                2200.0
#
#       Fuel_type Transmission  Price(euro)
# 0        Hybrid    Automatic       7750.0
# 1        Diesel       Manual       8550.0
# 2        Petrol       Manual       2200.0
# 3        Diesel       Manual       6550.0
# 4  Metan/Propan       Manual       4100.0
# 5        Diesel       Manual       3490.0

# %%
# Метод .head() датафрейма отображает заданное количество значений датафрейма с конца
DF.tail(9)
# Out:
#              Make         Model  Year      Style  Distance  \
# 37255     Renault        Megane  2011      Sedan  145000.0
# 37256      Toyota         Auris  2007  Hatchback  222111.0
# 37257       Skoda        Superb  2016  Cabriolet   78900.0
# 37258  Volkswagen        Passat  2016      Sedan   88000.0
# 37259  Land Rover    Freelander  2002  Crossover  225000.0
# 37260       Dacia     Logan Mcv  2015  Universal   89000.0
# 37261     Renault         Modus  2009  Hatchback     225.0
# 37262       Mazda             6  2006      Combi  370000.0
# 37263     Renault  Grand Scenic  2006    Minivan  300000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 37255                1500.0        Diesel    Automatic       6200.0
# 37256                1400.0        Diesel    Automatic       4444.0
# 37257                2000.0        Petrol    Automatic      21000.0
# 37258                1800.0        Petrol    Automatic      11500.0
# ...

# %%
# Атрибут .loc используется для получения среза датафрейма по заданным индексам и столбцам
DF.loc[1437,'Transmission']
# Out:
# 'Automatic'

# %%
DF.loc[:,'Transmission']
# Out:
# 0        Automatic
# 1           Manual
# 2           Manual
# 3           Manual
# 4           Manual
#            ...
# 37259       Manual
# 37260       Manual
# 37261       Manual
# 37262       Manual
# 37263       Manual
# Name: Transmission, Length: 37264, dtype: object

# %%
DF.loc[:,['Transmission']].head(5)
# Out:
#   Transmission
# 0    Automatic
# 1       Manual
# 2       Manual
# 3       Manual
# 4       Manual

# %%
DF.loc[:,['Transmission','Year']].head(5)
# Out:
#   Transmission  Year
# 0    Automatic  2011
# 1       Manual  2014
# 2       Manual  1998
# 3       Manual  2012
# 4       Manual  2006

# %%
DF.loc[:,'Make':'Style'].head(5)
# Out:
#          Make         Model  Year      Style
# 0      Toyota         Prius  2011  Hatchback
# 1     Renault  Grand Scenic  2014  Universal
# 2  Volkswagen          Golf  1998  Hatchback
# 3     Renault        Laguna  2012  Universal
# 4        Opel         Astra  2006  Universal

# %%
DF.loc[69,:]
# Out:
# Make                        Honda
# Model                        CR-V
# Year                         2002
# Style                   Universal
# Distance                 275100.0
# Engine_capacity(cm3)       2000.0
# Fuel_type                  Petrol
# Transmission               Manual
# Price(euro)                5900.0
# Name: 69, dtype: object

# %%
DF.loc[69:69,:]
# Out:
#      Make Model  Year      Style  Distance  Engine_capacity(cm3) Fuel_type  \
# 69  Honda  CR-V  2002  Universal  275100.0                2000.0    Petrol
#
#    Transmission  Price(euro)
# 69       Manual       5900.0

# %%
DF.loc[322:1437,:]
# Out:
#           Make     Model  Year      Style  Distance  Engine_capacity(cm3)  \
# 322      Skoda   Octavia  2010  Universal       1.0                1400.0
# 323   Mercedes   E Class  2016      Sedan  161024.0                2200.0
# 324      Honda     Civic  2006  Hatchback  195000.0                1400.0
# 325       Ford    Fusion  2015      Sedan  124000.0                2000.0
# 326       Ford    Fusion  2003  Hatchback  330000.0                1400.0
# ...        ...       ...   ...        ...       ...                   ...
# 1433   Peugeot       208  2013  Hatchback  154000.0                1400.0
# 1434  Infiniti      QX30  2017        SUV   91000.0                1500.0
# 1435      Ford      Kuga  2016        SUV  102500.0                1500.0
# 1436      Ford      Kuga  2018        SUV  122100.0                1500.0
# 1437       BMW  3 Series  2016      Sedan   64000.0                2000.0
#
#            Fuel_type Transmission  Price(euro)
# ...

# %%
DF.loc[227:229,'Make':'Fuel_type']
# Out:
#         Make    Model  Year      Style  Distance  Engine_capacity(cm3)  \
# 227     Opel  Calibra  1992      Coupe  400000.0                2000.0
# 228  Renault   Kadjar  2016  Crossover  150425.0                1500.0
# 229     Ford   Fusion  2018      Sedan  105000.0                2000.0
#
#         Fuel_type
# 227  Metan/Propan
# 228        Diesel
# 229        Hybrid

# %%
# pd.Dataframe поддерживает логическое индексирование столбцов. То есть можно
# отобрать строки по заданному условию, например, автомобили с механической коробкой передач
DF[DF['Transmission']=='Manual']
# Out:
#              Make         Model  Year      Style  Distance  \
# 1         Renault  Grand Scenic  2014  Universal  135000.0
# 2      Volkswagen          Golf  1998  Hatchback       1.0
# 3         Renault        Laguna  2012  Universal  110000.0
# 4            Opel         Astra  2006  Universal  200000.0
# 5        Mercedes          Vito  2000   Microvan  300000.0
# ...           ...           ...   ...        ...       ...
# 37259  Land Rover    Freelander  2002  Crossover  225000.0
# 37260       Dacia     Logan Mcv  2015  Universal   89000.0
# 37261     Renault         Modus  2009  Hatchback     225.0
# 37262       Mazda             6  2006      Combi  370000.0
# 37263     Renault  Grand Scenic  2006    Minivan  300000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 1                    1500.0        Diesel       Manual       8550.0
# 2                    1400.0        Petrol       Manual       2200.0
# ...

# %%
# Функция sort_values() возвращает датафрейм, со строками, отсортированными по заданному столбцу (параметр by)
DF.sort_values(by = 'Price(euro)').tail(5)
# Out:
#              Make               Model  Year      Style  Distance  \
# 13131      Toyota  Land Cruiser Prado  2012        SUV   10005.0
# 14834  Volkswagen               Caddy  2015      Combi  158260.0
# 29132    Mercedes             G Class  2020        SUV    3000.0
# 17849         KIA            Sportage  2018  Crossover   46000.0
# 33677  Brilliance                 BS3  2009      Sedan   57000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 13131                3000.0        Diesel    Automatic     200000.0
# 14834                1395.0  Metan/Propan       Manual     200000.0
# 29132                3982.0        Petrol    Automatic     215000.0
# 17849                1600.0        Petrol    Automatic     490000.0
# 33677                1598.0        Petrol       Manual   10000000.0

# %%
DF.sort_values(by = 'Year', ascending= False).head(5)
# Out:
#              Make      Model  Year      Style  Distance  Engine_capacity(cm3)  \
# 29164        Audi         A5  2021      Sedan     661.0                2000.0
# 32583    Mercedes  GLS Klass  2021        SUV       0.0                3000.0
# 15611  Volkswagen       Polo  2021  Universal  280000.0                1400.0
# 6044        Skoda     Superb  2021      Sedan       0.0                1500.0
# 11840      Toyota    Corolla  2021  Universal     288.0                1987.0
#
#       Fuel_type Transmission  Price(euro)
# 29164    Petrol    Automatic      32200.0
# 32583    Diesel    Automatic     107528.0
# 15611    Petrol       Manual       1900.0
# 6044     Petrol    Automatic      30000.0
# 11840    Hybrid    Automatic      23000.0

# %%
# Функция to_csv() позволяет вывести dataframe в csv файл для хранения и использования в других средах
DF.to_csv('/content/cars_moldova_no_dup.csv',index=False)

# %% [markdown]
# # Контрольные вопросы
#
# # 1. Назовите тип данных категориальных столбцов python
#
# Object
#
# # 2. Назовите целевой столбец для решения задачи регрессии
#
# Price(euro)
#
# # 3. Назовите целевой столбец для задачи классификации
#
# Transmission
#
# # 4. Возьмите датафрейм после удаления дубликатов. Выберете из полного датафрейма строки с индекса 69 по 322. Отсортируйте полученный датафрейм по колонке 'Distance' по убыванию. Какое значение колонки 'Style' у полученного датафрейма во второй строке сверху

# %%
ND_df = pd.read_csv('cars_moldova_no_dup.csv', delimiter=',')
sorted_df = ND_df.loc[69:322, :].sort_values(by = 'Distance', ascending=False)
sorted_df.iloc[1, 3]
# Out:
# 'Minivan'

# %% [markdown]
# # 5. Укажите правильную размерность исходного набора данных

# %%
# Атрибут shape датафрейма представляет собой кортеж,
# первое значение которого - число строк в датафрейме, второе - число столбцов
df.shape
# Out:
# (41007, 9)

# %% [markdown]
# # 6. Какие признаки называются дискретными, а какие непрерывными?
#
# Дискретные признаки можно посчитать но нельзя измерить (количество клиентов, количество закупаемых товаров). Принимают только целочисленные значения.
#
# Непрерывные признаки нельзя посчитать, но можно измерить (температура, уровень сахара в крови). Могут принимать дробные значения.

# %% [markdown]
# # 7. Опишите разницу между обучением с учителем и обучением без учителя.
#
# Обучения с учителем осуществляется с помощью размеченных данных (для каждого объекта указано значения целевой переменной, то есть класс для задачи классификации или числовое значение для задачи регрессии).
#
# При обучении без учителя используются неразмеченные данные. Это означает что модель должна сама определить, на какие классы может быть разделена выборка и уже потом научиться предсказывать класс каждого объекта.

# %% [markdown]
# # 8. Напишите разницу между задачами классификации и регрессии
#
# При решении задачи регресси модели необходимо найти числовое значение целевой переменной.
# Задача классификации предполагает определение принадлежности объекта к одному из предоставленных классов.

# %% [markdown]
# # 9. Если вас попросят создать программу, которая будет определять кошку или собаку по изображению, к какому типу задачмашинного обучения относится эта просьба?
# Это задача классификации

# %% [markdown]
# #10. Почему в качестве альтернативы простому использованию всехтренировочных данных рекомендуется выполнять проверку модели на валидационных данных?
#
# При проверке работы модели только с помощью тренировочных данных может возникнуть проблема переобучения - модель по сути просто запоминает тренировочную выборку вместо нахождения закономерностей. Для предотвращения этой проблемы используется проверка модели на новых данных, обычно они выделяются из тренировочной выборки. Такие данные называются валидационными.

# %% [markdown]
# # 11. Даны три матрицы A, B, C. Матрица A имеет размеры 5 × 4, B — размеры 4 × 6, C имеет размеры 3 × 5. Укажите все возможные матрицы, которые можно перемножить между собой.
#
# A x B, C x A

# %% [markdown]
# # 12. Найдите градиент функции f(x, y, z) = yx^2 + ln(y) + e^(-z)

# %% [markdown]
# # 13. Найдите частные производные сложной функции E = (y' - y)^2, y' = wx + b по переменным w и b
#
# Частная производная по w:
# dE/dw = 2 * (w * x + b - y) * d/dw(w*x+b) = 2x * (w * x + b - y)
#
# Частная производная по b: dE/db = 2 * (w * x + b - y) * d/db(w*x+b) = 2 * (w * x + b - y)

# %% [markdown]
# # 14. Найдите частные производные сложной функции E = y * ln(y') + (1 - y) * ln(1-y'), y' = 1/(1 + e^(-z)) по переменной z.
#
# F = y * ln(1/(1+e^(-z))) + (1 - y) * ln(e^(-x)) = -ln(1 + e^(-z) + (1-y)(-z)
#
# d/dz (-ln(1+e^(-z))) = - 1 / (1 + e^(-z)) * d/dz(1 + e^(-z)) = (-1 / (1 + e^(-z))) * (e^(-z)) = e^(-z) / 1 + e^(-z)
#
# d/dz ((1-y)(-z)) = -(1-y)
#
# dF/dz = e^(-z) / 1 + e^(-z) - (1-y)
#
# Т.к. y' = 1/1+e^(-z):
#
# dF/dz = (1-y') - (1-y) = y - y'
#
# Ответ: y - y'
